# %%
Num1=input("Enter Num1")
Num2=input("Enter Num2")
# Out:
# Enter Num1 5
# Enter Num2 6

# %%
print(Num1+Num2)
# Out:
# 56

# %%
Num3=int(input("Enter Num3"))
Num4=int(input("Enter Num4"))
# Out:
# Enter Num3 7
# Enter Num4 90

# %%
print(Num3+Num4)
# Out:
# 97

# %%
Fname=str(input("Enter your first name"))
Lname=str(input("Enter your last name"))
# Out:
# Enter your first name Monilka
# Enter your last name Karunadhika

# %%
Name=Fname+" "+Lname
print(Name)
# Out:
# Monilka Karunadhika

# %%
subject1=int(input("Enter the subject 1 marks."))
subject2=int(input("Enter the subject 2 marks."))
subject3=int(input("Enter the subject 3 marks."))
subject4=int(input("Enter the subject 4 marks."))
total=subject1+subject2+subject3+subject4
average=total/4
print(Name)
print(subject1)
print(subject2)
print(subject3)
print (subject4)
print(total)
print(average)
# Out:
# Enter the subject 1 marks. 72
# Enter the subject 2 marks. 79
# Enter the subject 3 marks. 86
# Enter the subject 4 marks. 93
# Monilka Karunadhika
# 72
# 79
# 86
# 93
# 330
# 82.5

# %%
print(Name,subject1,subject2)
# Out:
# Monilka Karunadhika 72 79
