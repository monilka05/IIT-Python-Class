# %%
name=input("Enter your name.")
marks=int(input("Enter your marks."))
if marks>80: grade="Grade A"
elif marks>=60: grade="Grade B"
elif marks>=40: grade="Grade C"
else: grade="Fail"
print(name, marks, grade)
# Out:
# Enter your name. Monilka
# Enter your marks. 78
# Monilka 78 Grade B
