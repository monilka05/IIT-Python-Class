# %%
print ("Hi IIT")
# Out:
# Hi IIT

# %% [markdown]
# # Variables

# %% [markdown]
# ## What are variables?

# %% [markdown]
# Memory spaces that hold information, such as numbers or text.

# %% [markdown]
# ## Variable Declaration and Verification

# %%
x=8
y="Sri Lanka"
z=10.5
print(x)
print(y)
print(z)
# Out:
# 8
# Sri Lanka
# 10.5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
print(type(z))
# Out:
# <class 'float'>
