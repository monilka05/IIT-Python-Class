# %% [markdown]
# # IIT Python Class

# %% [markdown]
# ## Week 01 Homework

# %% [markdown]
# very first command - print

# %%
print("Hello Everyone")
# Out:
# Hello Everyone

# %%
Print("IIT world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print("IIT world")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# print "p" should be simple.

# %% [markdown]
# () paranthesis

# %% [markdown]
# " double quotation

# %%
' single quotation

# %%
print('Hello Sri Lanka')
# Out:
# Hello Sri Lanka

# %%
print("My name is Monilka.")
print("I'm a university student.")
print("I study Biology.")
# Out:
# My name is Monilka.
# I'm a university student.
# I study Biology.
